# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
x = df['Name']
y = df['Age']
plt.plot(x,y)
plt.show()

# %%
x = df['Age']
plt.hist(x)
plt.show()

# %%
x = df['Fare']
plt.pie(x)
plt.show()

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df1 = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(df.total_bill,df.smoker)
sns.despine()
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='day')
plt.show()

# %%
sns.displot(df.sex)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='day',y='total_bill',data=df1)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=df,palette = 'PuRd')
# Out:
# <ipython-input-34-cd3e4fec2843>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day',y='total_bill',data=df,palette = 'PuRd')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df = sns.load_dataset('titanic')

# %%
sns.countplot(x='class',hue='who',data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.pointplot(x='day',y='tip',data=df1)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x='total_bill',y='tip',data=df1,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=df1,kind='kde')

# %%
sns.jointplot(x='total_bill',y='tip',data=df1,kind='hex')

# %%
sns.lmplot(x='total_bill',y='tip',data=df1,col='day',col_wrap=2,height=3)

# %%
sns.lmplot(x='total_bill',y='tip',data=df1,col='day',hue='sex',col_wrap=2,height=3)

# %%
sns.boxplot(x='day',y='total_bill',data=df1)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=df1,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=df1,split='True',hue='smoker')
sns.set_context('poster')

# %%
df2 = sns.load_dataset('flights')

# %%
df2.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
a = df2.pivot(index='month', columns='year', values='passengers')
a
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(a,linewidth=0.5)
sns.set_context('talk')

# %%
sns.catplot(data=df1, kind="swarm", x="day", y="total_bill", hue="smoker")
sns.set_context('paper')

# %%
sns.pairplot(data=df1, hue="smoker")
sns.set_context('notebook')
sns.set_style('darkgrid')
