# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/athul/Downloads/company_sales_data.csv")

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month_number  12 non-null     int64
#  1   facecream     12 non-null     int64
#  2   facewash      12 non-null     int64
#  3   toothpaste    12 non-null     int64
#  4   bathingsoap   12 non-null     int64
#  5   shampoo       12 non-null     int64
#  6   moisturizer   12 non-null     int64
#  7   total_units   12 non-null     int64
#  8   total_profit  12 non-null     int64
# dtypes: int64(9)
# memory usage: 996.0 bytes

# %%
df.describe()
# Out:
#        month_number    facecream     facewash   toothpaste   bathingsoap  \
# count     12.000000    12.000000    12.000000    12.000000     12.000000
# mean       6.500000  2873.333333  1542.916667  5825.833333   9500.833333
# std        3.605551   584.595172   316.733745  1242.032486   2348.095779
# min        1.000000  1990.000000  1120.000000  4550.000000   6100.000000
# 25%        3.750000  2460.000000  1305.000000  4862.500000   8015.000000
# 50%        6.500000  2830.000000  1527.500000  5530.000000   9090.000000
# 75%        9.250000  3435.000000  1765.000000  6400.000000  10045.000000
# max       12.000000  3700.000000  2100.000000  8300.000000  14400.000000
#
#            shampoo  moisturizer  total_units   total_profit
# count    12.000000    12.000000     12.00000      12.000000
# mean   2117.500000  1542.916667  26027.50000  260275.000000
# std     617.724931   316.733745   7014.36594   70143.659404
# min    1200.000000  1120.000000  18330.00000  183300.000000
# ...

# %%
plt.plot(df["total_profit"])
plt.xlabel("months")
plt.ylabel("total profit")
plt.grid()

# %%
plt.plot(df["total_profit"],color='red',marker='o',ls=':',lw='0.3')
plt.xlabel("months")
plt.ylabel("solid units")
plt.grid(ls=':',color='black')
plt.legend(['total_profit'],loc='lower right')

# %%
plt.suptitle("Multiline Plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(df["facecream"],color='red',marker='o')
plt.plot(df["facewash"],color='blue',marker='o')
plt.plot(df["toothpaste"],color='green',marker='o')
plt.plot(df["bathingsoap"],color='orange',marker='o')
plt.plot(df["shampoo"],color='violet',marker='o')
plt.plot(df["moisturizer"],color='cyan',marker='o')

# %%
df1=df['toothpaste']
df1
df2=df['month_number']
plt.scatter(df1,df2)

# %%
import matplotlib.pyplot as plt

# %%
# x=np.array([2,4,6,8,10])
# y=np.array([10,12,14,16,18])
x=df["facewash"].to_numpy()
y=df["facecream"].to_numpy()
plt.bar(x,y,width=30)
plt.title("Sales Data: Facewash vs Facecream")
plt.xlabel("Month")
plt.ylabel("Units Sold")
plt.legend(loc="upper right")
# plt.grid()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
bs=df["bathingsoap"]
bs
df2=df['month_number']
plt.barploy(bs,df2,color='r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 bs=df["bathingsoap"]
#       2 bs
#       3 df2=df['month_number']
#
# NameError: name 'df' is not defined

# %%
plt.hist(df["total_profit"])
# Out:
# (array([2., 4., 1., 1., 1., 1., 0., 1., 0., 1.]),
#  array([183300., 206250., 229200., 252150., 275100., 298050., 321000.,
#         343950., 366900., 389850., 412800.]),
#  <BarContainer object of 10 artists>)
