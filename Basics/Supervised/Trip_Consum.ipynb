# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.ensemble import RandomForestClassifier
#from sklearn.metrics import root_mean_squared_error

# %%
df = pd.read_csv('C:/Users/athul/Downloads/Energy_consumption/ETS-Data_Replication Explanatory File/Electric Vehicle Trip Energy Consumption Data.csv')

# %%
df.head()
# Out:
#    Trip Energy Consumption  Vehicle ID  Trip Distance  Time of Day  \
# 0                    0.672           1              6    10.333333
# 1                    0.896           1              6    16.000000
# 2                    1.344           1              7    16.090909
# 3                    1.344           1              8    19.000000
# 4                    0.896           1              6    14.166667
#
#    Day of the Week   Longitude   Latitude       Speed   Current  \
# 0                4  121.497948  31.281574  246.000000  2.583348
# 1                4  121.587564  31.256070  393.714286  2.985729
# 2                2  121.576968  31.262034  192.000000  2.354560
# 3                5  121.549709  31.257796  369.240000  1.540015
# 4                6  121.582280  31.215030  413.450617  9.659892
#
#    Total Voltage  Maximum Cell Temperature of Battery  \
# 0     308.283333                            31.000000
# 1     304.485714                            29.000000
# ...

# %%
df.isnull().sum()
# Out:
# Trip Energy Consumption                0
# Vehicle ID                             0
# Trip Distance                          0
# Time of Day                            0
# Day of the Week                        0
# Longitude                              0
# Latitude                               0
# Speed                                  0
# Current                                0
# Total Voltage                          0
# Maximum Cell Temperature of Battery    0
# Minimum Cell Temperature of Battery    0
# Trip Time Length                       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10151 entries, 0 to 10150
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Trip Energy Consumption              10151 non-null  float64
#  1   Vehicle ID                           10151 non-null  int64
#  2   Trip Distance                        10151 non-null  int64
#  3   Time of Day                          10151 non-null  float64
#  4   Day of the Week                      10151 non-null  int64
#  5   Longitude                            10151 non-null  float64
#  6   Latitude                             10151 non-null  float64
#  7   Speed                                10151 non-null  float64
#  8   Current                              10151 non-null  float64
#  9   Total Voltage                        10151 non-null  float64
#  10  Maximum Cell Temperature of Battery  10151 non-null  float64
# ...

# %%
df=df.drop('Vehicle ID',axis=1)

# %%
x = df.drop('Trip Energy Consumption',axis=1)

# %%
y = df['Trip Energy Consumption']

# %%
x
# Out:
#        Trip Distance  Time of Day  Day of the Week   Longitude   Latitude  \
# 0                  6    10.333333                4  121.497948  31.281574
# 1                  6    16.000000                4  121.587564  31.256070
# 2                  7    16.090909                2  121.576968  31.262034
# 3                  8    19.000000                5  121.549709  31.257796
# 4                  6    14.166667                6  121.582280  31.215030
# ...              ...          ...              ...         ...        ...
# 10146             36    14.500000                1  121.325082  31.263657
# 10147             28     0.325000                2  121.269958  31.343371
# 10148             43     1.562500                2  121.411333  31.053128
# 10149             18    21.808511                2  121.467157  30.854289
# 10150              6    23.000000                2  121.446612  30.903188
#
#             Speed   Current  Total Voltage  \
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
X_train.shape
# Out:
# (7105, 11)

# %%
X_test.shape
# Out:
# (3046, 11)

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
Y_pred = dt.predict(X_test)

# %%
Y_pred
# Out:
# array([6.048, 2.24 , 2.016, ..., 3.808, 2.24 , 2.016])

# %%
Y_test = np.array(Y_test)

# %%
Y_test
# Out:
# array([6.72 , 2.688, 1.792, ..., 5.824, 2.912, 1.792])

# %%
mse=mean_squared_error(Y_test,Y_pred)

# %%
mse
# Out:
# 1.8196954011818778

# %%
np.sqrt(mse)
# Out:
# 1.348960859766464

# %%
df['Trip Energy Consumption'].mean()
# Out:
# 3.9524492168259284

# %%
r2s=r2_score(Y_test,Y_pred)

# %%
r2s
# Out:
# 0.7747867856741057

# %%
#correlation_metrics

# %%
df.corr()
# Out:
#                                      Trip Energy Consumption  Trip Distance  \
# Trip Energy Consumption                             1.000000       0.915284
# Trip Distance                                       0.915284       1.000000
# Time of Day                                        -0.117176      -0.075393
# Day of the Week                                     0.023650       0.025168
# Longitude                                          -0.001871      -0.001383
# Latitude                                           -0.019821      -0.014960
# Speed                                               0.034594       0.050232
# Current                                             0.134976       0.055485
# Total Voltage                                      -0.098066      -0.029181
# Maximum Cell Temperature of Battery                 0.094071       0.147641
# Minimum Cell Temperature of Battery                 0.068034       0.132003
# ...
