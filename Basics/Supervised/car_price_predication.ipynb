# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/athul/Downloads/car-price-data.csv")

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0       1.0        3.0        alfa-romero giulia      gas        std
# 1       2.0        3.0       alfa-romero stelvio      gas        std
# 2       3.0        1.0  alfa-romero Quadrifoglio      gas        std
# 3       4.0        2.0               audi 100 ls      gas        std
# 4       5.0        2.0                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200   201.0       -1.0           volvo 145e (sw)      gas        std
# 201   202.0       -1.0               volvo 144ea      gas      turbo
# 202   203.0       -1.0               volvo 244dl      gas        std
# 203   204.0       -1.0                 volvo 246   diesel      turbo
# 204   205.0       -1.0               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.loc[:,'carwidth':'enginesize']
# Out:
#      carwidth  carheight  curbweight enginetype cylindernumber  enginesize
# 0        64.1       48.8      2548.0       dohc           four       130.0
# 1        64.1       48.8      2548.0       dohc           four       130.0
# 2        65.5       52.4      2823.0       ohcv            six       152.0
# 3        66.2       54.3      2337.0        ohc           four       109.0
# 4        66.4       54.3      2824.0        ohc           five       136.0
# ..        ...        ...         ...        ...            ...         ...
# 200      68.9       55.5      2952.0        ohc           four       141.0
# 201      68.8       55.5      3049.0        ohc           four       141.0
# 202      68.9       55.5      3012.0       ohcv            six       173.0
# 203      68.9       55.5      3217.0        ohc            six       145.0
# 204      68.9       55.5      3062.0        ohc           four       141.0
#
# [205 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# car_ID              1
# symboling           6
# CarName             3
# fueltype            2
# aspiration          2
# doornumber          1
# carbody             1
# drivewheel          1
# enginelocation      0
# wheelbase           2
# carlength           2
# carwidth            0
# carheight           0
# curbweight          3
# enginetype          0
# cylindernumber      1
# enginesize          1
# fuelsystem          1
# boreratio           0
# stroke              3
# compressionratio    1
# horsepower          2
# peakrpm             0
# citympg             1
# highwaympg          1
# price               0
# dtype: int64

# %%
null_mask = df.isnull().any(axis=1)
rows_with_nulls = df[null_mask]
print(rows_with_nulls)
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 6       7.0        1.0                audi 100ls      gas        std
# 19     20.0        1.0     chevrolet monte carlo      gas        std
# 21     22.0        1.0             dodge rampage      gas        std
# 23     24.0        1.0                dodge d200      gas        NaN
# 53     54.0        1.0                       NaN      gas        std
# 54     55.0        NaN          mazda glc deluxe      gas        std
# 66     67.0        0.0             mazda rx-7 gs   diesel        std
# 69     70.0        NaN             buick century   diesel      turbo
# 73     74.0        0.0     buick century special      gas        std
# 78     79.0        2.0      mitsubishi outlander      gas        std
# 87     88.0        NaN      mitsubishi outlander      gas      turbo
# 92     93.0        NaN              nissan latio      gas        std
# 119   120.0        1.0          plymouth cricket      gas      turbo
# ...

# %%
df.dropna(inplace=True)

# %%
ext= lambda x: x.split(' ')[0]

# %%
df["brand"]=df["CarName"].apply(ext)

# %%
ext1= lambda x: ' '.join(x.split(" ")[1:])

# %%
df["model"]=df["CarName"].apply(ext1)

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0       1.0        3.0        alfa-romero giulia      gas        std
# 1       2.0        3.0       alfa-romero stelvio      gas        std
# 2       3.0        1.0  alfa-romero Quadrifoglio      gas        std
# 3       4.0        2.0               audi 100 ls      gas        std
# 4       5.0        2.0                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 199   200.0       -1.0              volvo diesel      gas      turbo
# 200   201.0       -1.0           volvo 145e (sw)      gas        std
# 201   202.0       -1.0               volvo 144ea      gas      turbo
# 202   203.0       -1.0               volvo 244dl      gas        std
# 204   205.0       -1.0               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.dtypes
# Out:
# car_ID              float64
# symboling           float64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight          float64
# enginetype           object
# cylindernumber       object
# enginesize          float64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower          float64
# peakrpm               int64
# citympg             float64
# highwaympg          float64
# price               float64
# brand                object
# model                object
# dtype: object

# %%
cat=[]
num=[]
for i in df.columns:
    if df[i].dtype=='object':
        cat.append(i)
    else:
        num.append(i)

# %%
cat
# Out:
# ['CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
num
# Out:
# ['car_ID',
#  'symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
df=df.drop('car_ID',axis=1)

# %%
df=df.drop('CarName',axis=1)

# %%
df
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0          3.0        alfa-romero giulia      gas        std        two
# 1          3.0       alfa-romero stelvio      gas        std        two
# 2          1.0  alfa-romero Quadrifoglio      gas        std        two
# 3          2.0               audi 100 ls      gas        std       four
# 4          2.0                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 199       -1.0              volvo diesel      gas      turbo       four
# 200       -1.0           volvo 145e (sw)      gas        std       four
# 201       -1.0               volvo 144ea      gas      turbo       four
# 202       -1.0               volvo 244dl      gas        std       four
# 204       -1.0               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
df=df.drop(['brand','model'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 df=df.drop(['brand','model'],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# ...

# %%
df['doornumber'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
dict1={'four':4,'two':2}
df['doornumber']=df['doornumber'].apply(lambda x: dict1[x] if x in dict1 else x)

# %%
df['doornumber']
# Out:
# 0      2
# 1      2
# 2      2
# 3      4
# 4      4
#       ..
# 199    4
# 200    4
# 201    4
# 202    4
# 204    4
# Name: doornumber, Length: 176, dtype: int64

# %%
df['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
dict2={'four':4,'six':6,'five':5,'three':3,'twelve':12,'two':2,'eight':8}
df['cylindernumber']=df['cylindernumber'].apply(lambda x: dict2[x] if x in dict2 else x)

# %%
df['cylindernumber']
# Out:
# 0      4
# 1      4
# 2      6
# 3      4
# 4      5
#       ..
# 199    4
# 200    4
# 201    4
# 202    6
# 204    4
# Name: cylindernumber, Length: 176, dtype: int64

# %%
df[df['carlength']<170]
# Out:
#      symboling                    CarName fueltype aspiration  doornumber  \
# 0          3.0         alfa-romero giulia      gas        std           2
# 1          3.0        alfa-romero stelvio      gas        std           2
# 18         2.0           chevrolet impala      gas        std           2
# 20         0.0        chevrolet vega 2300      gas        std           4
# 22         1.0        dodge challenger se      gas        std           2
# ..         ...                        ...      ...        ...         ...
# 163        1.0    toyota corolla liftback      gas        std           2
# 164        1.0              toyota corona      gas        std           2
# 165        1.0  toyota celica gt liftback      gas        std           2
# 166        1.0      toyota corolla tercel      gas        std           2
# 189        3.0                  vw dasher      gas        std           2
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
df[df['carbody'].str.startswith("s")]
# Out:
#      symboling          CarName fueltype aspiration  doornumber carbody  \
# 3          2.0      audi 100 ls      gas        std           4   sedan
# 4          2.0       audi 100ls      gas        std           4   sedan
# 5          2.0         audi fox      gas        std           2   sedan
# 8          1.0        audi 4000      gas      turbo           4   sedan
# 10         2.0         bmw 320i      gas        std           2   sedan
# ..         ...              ...      ...        ...         ...     ...
# 198       -2.0      volvo 264gl      gas      turbo           4   sedan
# 200       -1.0  volvo 145e (sw)      gas        std           4   sedan
# 201       -1.0      volvo 144ea      gas      turbo           4   sedan
# 202       -1.0      volvo 244dl      gas        std           4   sedan
# 204       -1.0      volvo 264gl      gas      turbo           4   sedan
#
#     drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# ...

# %%
df[df['doornumber']==4]
# Out:
#      symboling          CarName fueltype aspiration  doornumber carbody  \
# 3          2.0      audi 100 ls      gas        std           4   sedan
# 4          2.0       audi 100ls      gas        std           4   sedan
# 7          1.0        audi 5000      gas        std           4   wagon
# 8          1.0        audi 4000      gas      turbo           4   sedan
# 11         0.0         bmw 320i      gas        std           4   sedan
# ..         ...              ...      ...        ...         ...     ...
# 199       -1.0     volvo diesel      gas      turbo           4   wagon
# 200       -1.0  volvo 145e (sw)      gas        std           4   sedan
# 201       -1.0      volvo 144ea      gas      turbo           4   sedan
# 202       -1.0      volvo 244dl      gas        std           4   sedan
# 204       -1.0      volvo 264gl      gas      turbo           4   sedan
#
#     drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# ...

# %%
df[df['carbody'].str.endswith("k")]
# Out:
#      symboling                    CarName fueltype aspiration  doornumber  \
# 2          1.0   alfa-romero Quadrifoglio      gas        std           2
# 9          0.0        audi 5000s (diesel)      gas      turbo           2
# 18         2.0           chevrolet impala      gas        std           2
# 22         1.0        dodge challenger se      gas        std           2
# 24         1.0          dodge monaco (sw)      gas        std           4
# 29         3.0  dodge coronet custom (sw)      gas      turbo           2
# 30         2.0                honda civic      gas        std           2
# 31         2.0           honda civic cvcc      gas        std           2
# 32         1.0                honda civic      gas        std           2
# 33         1.0          honda accord cvcc      gas        std           2
# 34         1.0           honda civic cvcc      gas        std           2
# 37         0.0               honda accord      gas        std           2
# ...

# %%
df.shape
# Out:
# (176, 25)

# %%
df[(df["price"]>=15000) & (df["doornumber"]==2)]
# Out:
#      symboling                          CarName fueltype aspiration  \
# 1          3.0              alfa-romero stelvio      gas        std
# 2          1.0         alfa-romero Quadrifoglio      gas        std
# 5          2.0                         audi fox      gas        std
# 9          0.0              audi 5000s (diesel)      gas      turbo
# 10         2.0                         bmw 320i      gas        std
# 12         0.0                           bmw x1      gas        std
# 16         0.0                           bmw x5      gas        std
# 49         0.0                        jaguar xk      gas        std
# 58         3.0                      mazda glc 4      gas        std
# 72         3.0                    buick skylark      gas        std
# 74         1.0  buick regal sport coupe (turbo)      gas        std
# 75         1.0                   mercury cougar      gas      turbo
# 104        3.0                     nissan teana      gas        std
# ...

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
le=LabelEncoder()

# %%
cat
# Out:
# ['CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
for i in cat:
    df[i]=le.fit_transform(df[i])

# %%
df[cat]
# Out:
#      CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          2         1           0           0        0           2
# 1          3         1           0           0        0           2
# 2          1         1           0           0        2           2
# 3          4         1           0           1        3           1
# 4          5         1           0           1        3           0
# ..       ...       ...         ...         ...      ...         ...
# 199      135         1           1           1        4           2
# 200      131         1           0           1        3           2
# 201      130         1           1           1        3           2
# 202      132         1           0           1        3           2
# 204      134         1           1           1        3           2
#
#      enginelocation  enginetype  cylindernumber  fuelsystem
# 0                 0           0               2           5
# ...

# %%
df['fuelsystem'].unique()
# Out:
# array([5, 1, 4, 0, 7, 2, 3, 6])

# %%
num = num[:-1]

# %%
se=StandardScaler()

# %%
df.dtypes
# Out:
# car_ID              float64
# symboling           float64
# CarName               int32
# fueltype              int32
# aspiration            int32
# doornumber            int64
# carbody               int32
# drivewheel            int32
# enginelocation        int32
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight          float64
# enginetype            int32
# cylindernumber        int64
# enginesize          float64
# fuelsystem            int32
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower          float64
# peakrpm               int64
# citympg             float64
# highwaympg          float64
# price               float64
# dtype: object

# %%
df[num]=se.fit_transform(df[num])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 df[num]=se.fit_transform(df[num])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# ...

# %%
df['compressionratio'].median()
# Out:
# -0.25993711079013654

# %%
df['price'].max()
# Out:
# 45400.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X=df.drop('price',axis=1)

# %%
Y=df['price']

# %%
Y.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 177   178.0       -1.0      118         1           0           1        2
# 145   146.0        0.0      103         1           1           1        3
# 116   117.0        0.0       80         0           1           1        3
# 89     90.0        1.0        0         1           0           0        3
# 40     41.0        0.0       31         1           0           1        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 81     82.0        3.0       58         1           0           0        2
# 118   119.0        1.0       86         1           0           0        2
# 15     16.0        0.0       13         1           0           1        3
# 104   105.0        3.0       77         1           0           0        2
# 114   115.0        0.0       82         0           1           1        4
#
# ...

# %%
X_test
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 22     23.0        1.0       24         1           0           0        2
# 49     50.0        0.0       45         1           0           0        3
# 159   160.0        0.0      108         0           0           1        2
# 34     35.0        1.0       38         1           0           0        2
# 76     77.0        2.0       60         1           0           0        2
# 17     18.0        0.0       12         1           0           1        3
# 134   135.0        3.0       97         1           0           0        2
# 200   201.0       -1.0      131         1           0           1        3
# 122   123.0        1.0       85         1           0           1        3
# 160   161.0        0.0      113         1           0           1        3
# 28     29.0       -1.0       29         1           0           1        4
# ...

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=lr.predict(X_test)

# %%
Y_test.mean()
# Out:
# 14117.971698113208

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse=mean_squared_error(Y_test,Y_pred)

# %%
mse
# Out:
# 15388567.371314684

# %%
(np.sqrt(mse)/Y_test.mean())*100
# Out:
# 27.78604841920596

# %%
r2s=r2_score(Y_test,Y_pred)

# %%
r2s
# Out:
# 0.8322442423301474

# %%
df.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0     1.0        3.0        2         1           0           0        0
# 1     2.0        3.0        3         1           0           0        0
# 2     3.0        1.0        1         1           0           0        2
# 3     4.0        2.0        4         1           0           1        3
# 4     5.0        2.0        5         1           0           1        3
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           2               0       88.6  ...       130.0           5
# 1           2               0       88.6  ...       130.0           5
# 2           2               0       94.5  ...       152.0           5
# 3           1               0       99.8  ...       109.0           5
# 4           0               0       99.4  ...       136.0           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
s,i = np.polyfit(df['horsepower'], df['price'],1)
line=s*np.array(df['horsepower'])+i
line
# Out:
# array([14422.65055967, 14422.65055967, 21680.88215879, 12903.48580637,
#        15097.83489447, 14253.85447597, 14253.85447597, 19317.73698699,
#        22693.658661  , 12734.68972267, 12734.68972267, 16110.61139668,
#        16110.61139668, 16110.61139668, 26407.17250241, 26407.17250241,
#        26407.17250241,  3788.49728654,  7502.01112795,  7164.41896055,
#         7164.41896055,  7164.41896055,  7164.41896055, 12903.48580637,
#        10540.34063456, 20161.71740549,  5476.45812355,  8514.78763015,
#         5814.05029095,  8514.78763015,  8514.78763015,  8514.78763015,
#         8514.78763015, 10202.74846716, 10202.74846716, 10202.74846716,
#        10202.74846716, 12734.68972267, 12565.89363897,  8852.37979756,
#         7502.01112795,  7502.01112795, 10877.93280196, 25394.3960002 ,
#        25394.3960002 , 39910.85919845,  7164.41896055,  7164.41896055,
#         7164.41896055, 12734.68972267, 12734.68972267, 12734.68972267,
# ...

# %%
x=df['horsepower']
y=df['price']
plt.scatter(x,y)
plt.plot(df['horsepower'],line)
