# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/athul/Downloads/kidney_disease.csv")

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
df.head(10)
# Out:
#    id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0   0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1   1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2   2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3   3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4   4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5   5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6   6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7   7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8   8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9   9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
#
#            ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# 0  notpresent  ...   44   7800  5.2  yes  yes   no  good   no   no
# 1  notpresent  ...   38   6000  NaN   no   no   no  good   no   no
# ...

# %%
df.tail(10)
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 390  390  52.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 391  391  36.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 392  392  57.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 393  393  43.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 394  394  50.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn  dm  cad appet  pe ane classification
# ...

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
df["rbc"].isnull()
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: rbc, Length: 400, dtype: bool

# %%
df[100:200]
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 100  100  34.0   70.0  1.015  4.0  0.0  abnormal  abnormal  notpresent
# 101  101  71.0   90.0  1.015  2.0  0.0       NaN  abnormal     present
# 102  102  17.0   60.0  1.010  0.0  0.0       NaN    normal  notpresent
# 103  103  76.0   70.0  1.015  2.0  0.0    normal  abnormal     present
# 104  104  55.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent
# ..   ...   ...    ...    ...  ...  ...       ...       ...         ...
# 195  195  70.0   90.0  1.020  2.0  1.0  abnormal  abnormal  notpresent
# 196  196  49.0  100.0  1.010  3.0  0.0  abnormal  abnormal  notpresent
# 197  197  57.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 198  198  59.0  100.0  1.020  4.0  2.0    normal    normal  notpresent
# 199  199  65.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
df["classification"].value_counts()
# Out:
# classification
# ckd       250
# notckd    150
# Name: count, dtype: int64

# %%
df.replace({"ckd\t":"ckd"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
df=df.drop({"id","pc","pcc","pot","htn","dm"},axis='columns')

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'ba', 'bgr', 'bu', 'sc', 'sod',
#        'hemo', 'pcv', 'wc', 'rc', 'cad', 'appet', 'pe', 'ane',
#        'classification'],
#       dtype='object')

# %%
df.head()
# Out:
#      age    bp     sg   al   su       rbc          ba    bgr     bu   sc  \
# 3   48.0  70.0  1.005  4.0  0.0    normal  notpresent  117.0   56.0  3.8
# 9   53.0  90.0  1.020  2.0  0.0  abnormal  notpresent   70.0  107.0  7.2
# 11  63.0  70.0  1.010  3.0  0.0  abnormal  notpresent  380.0   60.0  2.7
# 14  68.0  80.0  1.010  3.0  2.0    normal     present  157.0   90.0  4.1
# 20  61.0  80.0  1.015  2.0  0.0  abnormal  notpresent  173.0  148.0  3.9
#
#       sod  hemo pcv     wc   rc  cad appet   pe  ane classification
# 3   111.0  11.2  32   6700  3.9   no  poor  yes  yes            ckd
# 9   114.0   9.5  29  12100  3.7   no  poor   no  yes            ckd
# 11  131.0  10.8  32   4500  3.8   no  poor  yes   no            ckd
# 14  130.0   5.6  16  11000  2.6  yes  poor  yes   no            ckd
# 20  135.0   7.7  24   9200  3.2  yes  poor  yes  yes            ckd

# %%
df.dropna(inplace=True)
