# %%
import pandas as pd
import numpy as np

# %%
dict1={"name":"athul","age":20,"course":"MCA"}
pd.Series(dict1)
# Out:
# name      athul
# age          20
# course      MCA
# dtype: object

# %%
dict2={"name":["athul","arun","varun"],"age":["21","23","30"],"course":["mca","bca","mba"]}
print(dict2)
df=pd.DataFrame(dict2)
print(df)
# Out:
# {'name': ['athul', 'arun', 'varun'], 'age': ['21', '23', '30'], 'course': ['mca', 'bca', 'mba']}
#     name age course
# 0  athul  21    mca
# 1   arun  23    bca
# 2  varun  30    mba

# %%
df=pd.read_csv("C:/Users/athul/Downloads/car-price-data.csv")

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0       1.0        3.0        alfa-romero giulia      gas        std
# 1       2.0        3.0       alfa-romero stelvio      gas        std
# 2       3.0        1.0  alfa-romero Quadrifoglio      gas        std
# 3       4.0        2.0               audi 100 ls      gas        std
# 4       5.0        2.0                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200   201.0       -1.0           volvo 145e (sw)      gas        std
# 201   202.0       -1.0               volvo 144ea      gas      turbo
# 202   203.0       -1.0               volvo 244dl      gas        std
# 203   204.0       -1.0                 volvo 246   diesel      turbo
# 204   205.0       -1.0               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0     1.0        3.0        alfa-romero giulia      gas        std        two
# 1     2.0        3.0       alfa-romero stelvio      gas        std        two
# 2     3.0        1.0  alfa-romero Quadrifoglio      gas        std        two
# 3     4.0        2.0               audi 100 ls      gas        std       four
# 4     5.0        2.0                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...       130.0
# 1  convertible        rwd          front       88.6  ...       130.0
# 2    hatchback        rwd          front       94.5  ...       152.0
# 3        sedan        fwd          front       99.8  ...       109.0
# 4        sedan        4wd          front       99.4  ...       136.0
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200   201.0       -1.0  volvo 145e (sw)      gas        std       four
# 201   202.0       -1.0      volvo 144ea      gas      turbo       four
# 202   203.0       -1.0      volvo 244dl      gas        std       four
# 203   204.0       -1.0        volvo 246   diesel      turbo       four
# 204   205.0       -1.0      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...       141.0        mpfi
# 201   sedan        rwd          front      109.1  ...       141.0        mpfi
# 202   sedan        rwd          front      109.1  ...       173.0        mpfi
# 203   sedan        rwd          front      109.1  ...       145.0         NaN
# 204   sedan        rwd          front      109.1  ...       141.0        mpfi
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            204 non-null    float64
#  1   symboling         199 non-null    float64
#  2   CarName           202 non-null    object
#  3   fueltype          203 non-null    object
#  4   aspiration        203 non-null    object
#  5   doornumber        204 non-null    object
#  6   carbody           204 non-null    object
#  7   drivewheel        204 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         203 non-null    float64
#  10  carlength         203 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        202 non-null    float64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    204 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase  carlength    carwidth   carheight  \
# count  204.000000  199.000000  203.000000  203.00000  205.000000  205.000000
# mean   102.539216    0.834171   98.779310  174.03399   65.907805   53.724878
# std     59.099594    1.258361    6.044002   12.39710    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.10000   60.300000   47.800000
# 25%     51.750000    0.000000   94.500000  166.30000   64.100000   52.000000
# 50%    102.500000    1.000000   97.000000  173.20000   65.500000   54.100000
# 75%    153.250000    2.000000  102.400000  183.30000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.10000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   202.000000  204.000000  205.000000  202.000000        204.000000
# mean   2558.603960  126.931373    3.329756    3.260495         10.145196
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df[df["CarName"]=="audi 100 ls"]
# Out:
#    car_ID  symboling      CarName fueltype aspiration doornumber carbody  \
# 3     4.0        2.0  audi 100 ls      gas        std       four   sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 3        fwd          front       99.8  ...       109.0        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# 3       3.19     3.4             10.0      102.0     5500    24.0        30.0
#
#      price
# 3  13950.0
#
# [1 rows x 26 columns]

# %%
df.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0     1.0        3.0        alfa-romero giulia      gas        std        two
# 1     2.0        3.0       alfa-romero stelvio      gas        std        two
# 2     3.0        1.0  alfa-romero Quadrifoglio      gas        std        two
# 3     4.0        2.0               audi 100 ls      gas        std       four
# 4     5.0        2.0                audi 100ls      gas        std       four
# 5     6.0        2.0                  audi fox      gas        std        two
# 6     7.0        1.0                audi 100ls      gas        std       four
# 7     8.0        1.0                 audi 5000      gas        std       four
# 8     9.0        1.0                 audi 4000      gas      turbo       four
# 9    10.0        0.0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
df[100:150]
# Out:
#      car_ID  symboling                         CarName fueltype aspiration  \
# 100   101.0        0.0                    nissan nv200      gas        std
# 101   102.0        0.0                     nissan dayz      gas        std
# 102   103.0        0.0                     nissan fuga      gas        std
# 103   104.0        0.0                     nissan otti      gas        std
# 104   105.0        3.0                    nissan teana      gas        std
# 105   106.0        3.0                    nissan kicks      gas      turbo
# 106   107.0        1.0                  nissan clipper      gas        std
# 107   108.0        0.0                     peugeot 504      gas        std
# 108   109.0        0.0                     peugeot 304   diesel      turbo
# 109   110.0        0.0                peugeot 504 (sw)      gas        std
# 110   111.0        0.0                     peugeot 504   diesel      turbo
# ...

# %%
df=df[(df["price"]>=13200.0 ) & (df["horsepower"]==160.0)]

# %%
df
# Out:
#      car_ID  symboling              CarName fueltype aspiration doornumber  \
# 9      10.0        0.0  audi 5000s (diesel)      gas      turbo        two
# 104   105.0        3.0         nissan teana      gas        std        two
# 106   107.0        1.0       nissan clipper      gas        std        two
# 136   137.0        3.0                  NaN      gas      turbo        two
# 137   138.0        2.0             saab 99e      gas      turbo       four
# 201   202.0       -1.0          volvo 144ea      gas      turbo       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 9    hatchback        4wd          front       99.5  ...       131.0
# 104  hatchback        rwd          front       91.3  ...       181.0
# 106  hatchback        rwd          front       99.2  ...       181.0
# 136  hatchback        NaN          front       99.1  ...       121.0
# 137      sedan        fwd          front       99.1  ...       121.0
# ...

# %%
# df[df["CarName"].str.startswith("a")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df[df["CarName"].str.startswith("a")]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3883, in DataFrame.__getitem__(self, key)
#    3880     return self.where(key)
#    3882 # Do we have a (boolean) 1d indexer?
# -> 3883 if com.is_bool_indexer(key):
#    3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:133, in is_bool_indexer(key)
#     129     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     130     if lib.is_bool_array(key_array, skipna=True):
#     131         # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %%
df.isnull()
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 9     False      False    False     False       False       False    False
# 104   False      False    False     False       False       False    False
# 106   False      False    False     False       False       False    False
# 136   False      False     True     False       False       False    False
# 137   False      False    False     False       False       False    False
# 201   False      False    False     False       False       False    False
#
#      drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 9         False           False      False  ...       False       False
# 104       False           False      False  ...       False       False
# 106       False           False      False  ...       False       False
# 136        True           False      False  ...       False       False
# 137       False           False      False  ...       False       False
# ...

# %%
df.notnull()
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0      True       True     True      True        True        True     True
# 1      True       True     True      True        True        True     True
# 2      True       True     True      True        True        True     True
# 3      True       True     True      True        True        True     True
# 4      True       True     True      True        True        True     True
# ..      ...        ...      ...       ...         ...         ...      ...
# 200    True       True     True      True        True        True     True
# 201    True       True     True      True        True        True     True
# 202    True       True     True      True        True        True     True
# 203    True       True     True      True        True        True     True
# 204    True       True     True      True        True        True     True
#
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              1
# symboling           6
# CarName             3
# fueltype            2
# aspiration          2
# doornumber          1
# carbody             1
# drivewheel          1
# enginelocation      0
# wheelbase           2
# carlength           2
# carwidth            0
# carheight           0
# curbweight          3
# enginetype          0
# cylindernumber      1
# enginesize          1
# fuelsystem          1
# boreratio           0
# stroke              3
# compressionratio    1
# horsepower          2
# peakrpm             0
# citympg             1
# highwaympg          1
# price               0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# car_ID              204
# symboling           199
# CarName             202
# fueltype            203
# aspiration          203
# doornumber          204
# carbody             204
# drivewheel          204
# enginelocation      205
# wheelbase           203
# carlength           203
# carwidth            205
# carheight           205
# curbweight          202
# enginetype          205
# cylindernumber      204
# enginesize          204
# fuelsystem          204
# boreratio           205
# stroke              202
# compressionratio    204
# horsepower          203
# peakrpm             205
# citympg             204
# highwaympg          204
# price               205
# dtype: int64

# %%
df["symboling"].notnull().sum()
# Out:
# 199

# %%
df.dropna(inplace=True)

# %%
df.dropna(axis=1,inplace=True)

# %%
df.shape
# Out:
# (205, 7)

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df["symboling"]=df["symboling"].fillna(df["symboling"].mean())

# %%
df["symboling"].isnull().sum()
# Out:
# 0

# %%
df.loc[54]
# Out:
# car_ID                          55.0
# symboling                   0.834171
# CarName             mazda glc deluxe
# fueltype                         gas
# aspiration                       std
# doornumber                      four
# carbody                        sedan
# drivewheel                       fwd
# enginelocation                 front
# wheelbase                       93.1
# carlength                      166.8
# carwidth                        64.2
# carheight                       54.1
# curbweight                    1950.0
# enginetype                       ohc
# cylindernumber                  four
# enginesize                      91.0
# fuelsystem                      2bbl
# boreratio                       3.08
# stroke                          3.15
# compressionratio                 9.0
# horsepower                      68.0
# peakrpm                         5000
# citympg                         31.0
# highwaympg                      38.0
# ...

# %%
df["CarName"]=df["CarName"].ffill()

# %%
df.isnull().sum()
# Out:
# car_ID              1
# symboling           6
# CarName             3
# fueltype            2
# aspiration          2
# doornumber          1
# carbody             1
# drivewheel          1
# enginelocation      0
# wheelbase           2
# carlength           2
# carwidth            0
# carheight           0
# curbweight          3
# enginetype          0
# cylindernumber      1
# enginesize          1
# fuelsystem          1
# boreratio           0
# stroke              3
# compressionratio    1
# horsepower          2
# peakrpm             0
# citympg             1
# highwaympg          1
# price               0
# dtype: int64

# %%
df["symboling"].isnull().sum()
# Out:
# 6

# %%
df[df["symboling"].isnull()]
# Out:
#      car_ID  symboling               CarName fueltype aspiration doornumber  \
# 54     55.0        NaN      mazda glc deluxe      gas        std       four
# 69     70.0        NaN         buick century   diesel      turbo        two
# 87     88.0        NaN  mitsubishi outlander      gas      turbo       four
# 92     93.0        NaN          nissan latio      gas        std       four
# 156   157.0        NaN        toyota mark ii      gas        std       four
# 171   172.0        NaN        toyota corolla      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 54       sedan        fwd          front       93.1  ...        91.0
# 69     hardtop        rwd          front      106.7  ...       183.0
# 87       sedan        fwd          front       96.3  ...       110.0
# 92       sedan        fwd          front       94.5  ...        97.0
# 156      sedan        fwd          front       95.7  ...        98.0
# ...

# %%
df["symboling"]=df["symboling"].fillna(df["symboling"].mean())

# %%
df[df["symboling"].isnull()]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CarName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
df["symboling"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# car_ID              1
# symboling           0
# CarName             3
# fueltype            2
# aspiration          2
# doornumber          1
# carbody             1
# drivewheel          1
# enginelocation      0
# wheelbase           2
# carlength           2
# carwidth            0
# carheight           0
# curbweight          3
# enginetype          0
# cylindernumber      1
# enginesize          1
# fuelsystem          1
# boreratio           0
# stroke              3
# compressionratio    1
# horsepower          2
# peakrpm             0
# citympg             1
# highwaympg          1
# price               0
# dtype: int64

# %%
df["CarName"]
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object

# %%
df["CarName"]=df["CarName"].ffill()

# %%
df[50:55]
# Out:
#     car_ID  symboling           CarName fueltype aspiration doornumber  \
# 50    51.0        1.0         maxda rx3      gas        std        two
# 51    52.0        1.0  maxda glc deluxe      gas        std        two
# 52    53.0        1.0   mazda rx2 coupe      gas        std        two
# 53    54.0        1.0               NaN      gas        std       four
# 54    55.0        NaN  mazda glc deluxe      gas        std       four
#
#       carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 50  hatchback        fwd          front       93.1  ...        91.0
# 51  hatchback        fwd          front       93.1  ...        91.0
# 52  hatchback        fwd          front       93.1  ...        91.0
# 53      sedan        fwd          front       93.1  ...        91.0
# 54      sedan        fwd          front       93.1  ...        91.0
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# ...

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0     1.0        3.0        alfa-romero giulia      gas        std        two
# 1     2.0        3.0       alfa-romero stelvio      gas        std        two
# 2     3.0        1.0  alfa-romero Quadrifoglio   petrol        std        two
# 3     4.0        2.0               audi 100 ls      gas        std       four
# 4     5.0        2.0                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...       130.0
# 1  convertible        rwd          front       88.6  ...       130.0
# 2    hatchback        rwd          front       94.5  ...       152.0
# 3        sedan        fwd          front       99.8  ...       109.0
# 4        sedan        4wd          front       99.4  ...       136.0
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.loc[2,"fueltype"]="petrol"

# %%
df["CarName"] = df["CarName"].fillna(df["CarName"].mode()[0])

# %%
df[50:55]
# Out:
#     car_ID  symboling           CarName fueltype aspiration doornumber  \
# 50    51.0        1.0         maxda rx3      gas        std        two
# 51    52.0        1.0  maxda glc deluxe      gas        std        two
# 52    53.0        1.0   mazda rx2 coupe      gas        std        two
# 53    54.0        1.0  mazda glc deluxe      gas        std       four
# 54    55.0        NaN  mazda glc deluxe      gas        std       four
#
#       carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 50  hatchback        fwd          front       93.1  ...        91.0
# 51  hatchback        fwd          front       93.1  ...        91.0
# 52  hatchback        fwd          front       93.1  ...        91.0
# 53      sedan        fwd          front       93.1  ...        91.0
# 54      sedan        fwd          front       93.1  ...        91.0
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0       1.0        3.0        alfa-romero giulia      gas        std
# 1       2.0        3.0       alfa-romero stelvio      gas        std
# 2       3.0        1.0  alfa-romero Quadrifoglio   petrol        std
# 3       4.0        2.0               audi 100 ls      gas        std
# 4       5.0        2.0                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200   201.0       -1.0           volvo 145e (sw)      gas        std
# 201   202.0       -1.0               volvo 144ea      gas      turbo
# 202   203.0       -1.0               volvo 244dl      gas        std
# 203   204.0       -1.0                 volvo 246   diesel      turbo
# 204   205.0       -1.0               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
list1=[]
for i in df.columns:
    if df[i].dtype=="int64" or df[i].dtype=="float64":
        list1.append(i)

# %%
list1
# Out:
# ['car_ID',
#  'symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
df[list1].head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0     1.0        3.0       88.6      168.8      64.1       48.8      2548.0
# 1     2.0        3.0       88.6      168.8      64.1       48.8      2548.0
# 2     3.0        1.0       94.5      171.2      65.5       52.4      2823.0
# 3     4.0        2.0       99.8      176.6      66.2       54.3      2337.0
# 4     5.0        2.0       99.4      176.6      66.4       54.3      2824.0
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0       130.0       3.47    2.68               9.0       111.0     5000
# 1       130.0       3.47    2.68               9.0       111.0     5000
# 2       152.0       2.68    3.47               9.0       154.0     5000
# 3       109.0       3.19    3.40              10.0       102.0     5500
# 4       136.0       3.19    3.40               8.0       115.0     5500
#
#    citympg  highwaympg    price
# 0     21.0        27.0  13495.0
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.corr()
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt

# %%
# y=df["wheelbase"]
# x=df["fueltype"]
# plt.bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 y=df["wheelbase"]
#       2 x=df["fueltype"]
# ----> 3 plt.bar(x,y)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2742, in bar(x, height, width, bottom, align, data, **kwargs)
#    2731 @_copy_docstring_and_deprecators(Axes.bar)
#    2732 def bar(
#    2733     x: float | ArrayLike,
#    (...)
#    2740     **kwargs,
#    2741 ) -> BarContainer:
# -> 2742     return gca().bar(
#    2743         x,
#    2744         height,
#    2745         width=width,
#    2746         bottom=bottom,
#    2747         align=align,
#    2748         **({"data": data} if data is not None else {}),
#    2749         **kwargs,
#    2750     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
# ...

# %%
df.nunique()
# Out:
# car_ID              204
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          169
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
df["fueltype"].unique()
# Out:
# array(['gas', 'diesel', nan], dtype=object)

# %%
ext=lambda x:x.split(' ')[0]

# %%
df["CarName"].astype(str)
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object

# %%
df["brand"]= df["CarName"].apply(ext)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df["brand"]= df["CarName"].apply(ext)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1209, in SeriesApply.apply(self)
# ...
